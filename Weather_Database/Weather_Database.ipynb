# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
import time
from citipy import citipy
# Import API key
from config import weather_api_key
import gmaps

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lat_lngs)

# %%
#Create a list for holding the names of cities.
cities = []
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 713

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="

city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    
    city_url = url + weather_api_key + "&q=" + city.replace(" ", "+")
    
    try:
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")

        
        city_data.append({
                          "City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date
                        })
        
    except KeyError:
        print("City not found. Skipping...")
        continue
        
    print(f"Processing record count {record_count} of set {set_count} | {city}")
    record_count += 1
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing record count 1 of set 1 | arraial do cabo
# Processing record count 2 of set 1 | hobart
# Processing record count 3 of set 1 | hermanus
# Processing record count 4 of set 1 | victoria
# Processing record count 5 of set 1 | cape town
# City not found. Skipping...
# Processing record count 6 of set 1 | vestmannaeyjar
# Processing record count 7 of set 1 | chernyshevskiy
# Processing record count 8 of set 1 | tasiilaq
# Processing record count 9 of set 1 | faya
# Processing record count 10 of set 1 | ahipara
# Processing record count 11 of set 1 | mataura
# Processing record count 12 of set 1 | mahebourg
# Processing record count 13 of set 1 | rikitea
# Processing record count 14 of set 1 | yellowknife
# Processing record count 15 of set 1 | uyovu
# Processing record count 16 of set 1 | punta arenas
# Processing record count 17 of set 1 | qaanaaq
# City not found. Skipping...
# Processing record count 18 of set 1 | campbellsville
# Processing record count 19 of set 1 | thompson
# Processing record count 20 of set 1 | grindavik
# Processing record count 21 of set 1 | ushuaia
# Processing record count 22 of set 1 | talnakh
# City not found. Skipping...
# Processing record count 23 of set 1 | busselton
# Processing record count 24 of set 1 | carnarvon
# Processing record count 25 of set 1 | saint-philippe
# City not found. Skipping...
# Processing record count 26 of set 1 | jamestown
# Processing record count 27 of set 1 | grandview
# Processing record count 28 of set 1 | goderich
# Processing record count 29 of set 1 | castro
# Processing record count 30 of set 1 | leningradskiy
# Processing record count 31 of set 1 | kapaa
# Processing record count 32 of set 1 | nikolskoye
# Processing record count 33 of set 1 | tuktoyaktuk
# Processing record count 34 of set 1 | bluff
# Processing record count 35 of set 1 | nathdwara
# Processing record count 36 of set 1 | provideniya
# Processing record count 37 of set 1 | coihueco
# Processing record count 38 of set 1 | bambous virieux
# Processing record count 39 of set 1 | ornskoldsvik
# City not found. Skipping...
# Processing record count 40 of set 1 | mar del plata
# City not found. Skipping...
# Processing record count 41 of set 1 | saint-georges
# Processing record count 42 of set 1 | saquarema
# Processing record count 43 of set 1 | dingle
# City not found. Skipping...
# Processing record count 1 of set 2 | port elizabeth
# Processing record count 2 of set 2 | dikson
# Processing record count 3 of set 2 | tuatapere
# Processing record count 4 of set 2 | hamilton
# Processing record count 5 of set 2 | hilo
# City not found. Skipping...
# Processing record count 6 of set 2 | albany
# Processing record count 7 of set 2 | tucupita
# Processing record count 8 of set 2 | vardo
# Processing record count 9 of set 2 | ancud
# Processing record count 10 of set 2 | bredasdorp
# Processing record count 11 of set 2 | san fernando
# Processing record count 12 of set 2 | lebu
# Processing record count 13 of set 2 | kodiak
# Processing record count 14 of set 2 | barrow
# Processing record count 15 of set 2 | khandyga
# Processing record count 16 of set 2 | petauke
# City not found. Skipping...
# Processing record count 17 of set 2 | port alfred
# Processing record count 18 of set 2 | pangoa
# Processing record count 19 of set 2 | guerrero negro
# Processing record count 20 of set 2 | san andres
# Processing record count 21 of set 2 | port moresby
# Processing record count 22 of set 2 | kauhajoki
# Processing record count 23 of set 2 | rio gallegos
# Processing record count 24 of set 2 | puerto ayora
# Processing record count 25 of set 2 | avarua
# Processing record count 26 of set 2 | qitaihe
# Processing record count 27 of set 2 | ilulissat
# Processing record count 28 of set 2 | praia da vitoria
# Processing record count 29 of set 2 | zyryanka
# Processing record count 30 of set 2 | gat
# Processing record count 31 of set 2 | ambon
# Processing record count 32 of set 2 | berdigestyakh
# Processing record count 33 of set 2 | geraldton
# Processing record count 34 of set 2 | tiksi
# Processing record count 35 of set 2 | coquimbo
# Processing record count 36 of set 2 | georgetown
# Processing record count 37 of set 2 | yar-sale
# Processing record count 38 of set 2 | rocha
# Processing record count 39 of set 2 | clyde river
# Processing record count 40 of set 2 | houma
# Processing record count 41 of set 2 | ternate
# Processing record count 42 of set 2 | butaritari
# City not found. Skipping...
# Processing record count 43 of set 2 | wadena
# Processing record count 44 of set 2 | marsh harbour
# Processing record count 45 of set 2 | san juan
# City not found. Skipping...
# Processing record count 46 of set 2 | rawson
# Processing record count 1 of set 3 | port blair
# Processing record count 2 of set 3 | togur
# Processing record count 3 of set 3 | naze
# Processing record count 4 of set 3 | senno
# Processing record count 5 of set 3 | mount gambier
# Processing record count 6 of set 3 | bairiki
# Processing record count 7 of set 3 | cedar city
# Processing record count 8 of set 3 | ribeira grande
# Processing record count 9 of set 3 | auki
# Processing record count 10 of set 3 | atuona
# Processing record count 11 of set 3 | fairbanks
# Processing record count 12 of set 3 | iqaluit
# Processing record count 13 of set 3 | acarau
# Processing record count 14 of set 3 | ponta do sol
# City not found. Skipping...
# Processing record count 15 of set 3 | taltal
# Processing record count 16 of set 3 | kununurra
# Processing record count 17 of set 3 | letka
# Processing record count 18 of set 3 | east london
# Processing record count 19 of set 3 | aginskoye
# Processing record count 20 of set 3 | straumen
# Processing record count 21 of set 3 | stornoway
# Processing record count 22 of set 3 | bethel
# Processing record count 23 of set 3 | ust-maya
# Processing record count 24 of set 3 | tromso
# Processing record count 25 of set 3 | saskylakh
# City not found. Skipping...
# Processing record count 26 of set 3 | port hawkesbury
# Processing record count 27 of set 3 | kigali
# Processing record count 28 of set 3 | belmonte
# Processing record count 29 of set 3 | port hardy
# Processing record count 30 of set 3 | alyangula
# Processing record count 31 of set 3 | richards bay
# Processing record count 32 of set 3 | vaini
# City not found. Skipping...
# Processing record count 33 of set 3 | locri
# Processing record count 34 of set 3 | beyneu
# Processing record count 35 of set 3 | codrington
# Processing record count 36 of set 3 | esso
# Processing record count 37 of set 3 | alofi
# Processing record count 38 of set 3 | kopavogur
# Processing record count 39 of set 3 | katsuura
# Processing record count 40 of set 3 | ouesso
# Processing record count 41 of set 3 | beisfjord
# Processing record count 42 of set 3 | sioux lookout
# Processing record count 43 of set 3 | beloha
# Processing record count 44 of set 3 | airai
# Processing record count 45 of set 3 | saskatoon
# Processing record count 46 of set 3 | olafsvik
# Processing record count 47 of set 3 | buraydah
# Processing record count 1 of set 4 | fuerte olimpo
# Processing record count 2 of set 4 | hasaki
# Processing record count 3 of set 4 | cherskiy
# Processing record count 4 of set 4 | lata
# Processing record count 5 of set 4 | sao felix do xingu
# Processing record count 6 of set 4 | xuddur
# Processing record count 7 of set 4 | aksu
# Processing record count 8 of set 4 | wenling
# Processing record count 9 of set 4 | namatanai
# Processing record count 10 of set 4 | anadyr
# Processing record count 11 of set 4 | new norfolk
# Processing record count 12 of set 4 | erzin
# Processing record count 13 of set 4 | honiara
# Processing record count 14 of set 4 | chuy
# City not found. Skipping...
# Processing record count 15 of set 4 | adrar
# Processing record count 16 of set 4 | nanortalik
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 17 of set 4 | margate
# Processing record count 18 of set 4 | westport
# Processing record count 19 of set 4 | jiaojiang
# Processing record count 20 of set 4 | owando
# Processing record count 21 of set 4 | khatanga
# Processing record count 22 of set 4 | dzilam gonzalez
# Processing record count 23 of set 4 | tonantins
# Processing record count 24 of set 4 | faro
# Processing record count 25 of set 4 | carutapera
# Processing record count 26 of set 4 | ciudad bolivar
# Processing record count 27 of set 4 | sisimiut
# Processing record count 28 of set 4 | griffith
# Processing record count 29 of set 4 | arvin
# Processing record count 30 of set 4 | mandiana
# Processing record count 31 of set 4 | pisco
# Processing record count 32 of set 4 | gubkinskiy
# Processing record count 33 of set 4 | vikhorevka
# Processing record count 34 of set 4 | bure
# Processing record count 35 of set 4 | chumikan
# Processing record count 36 of set 4 | oranjemund
# Processing record count 37 of set 4 | saint anthony
# Processing record count 38 of set 4 | kresek
# Processing record count 39 of set 4 | maraa
# City not found. Skipping...
# Processing record count 40 of set 4 | ayan
# Processing record count 41 of set 4 | estepona
# Processing record count 42 of set 4 | verkhnyaya inta
# Processing record count 43 of set 4 | chabahar
# Processing record count 44 of set 4 | esperance
# Processing record count 45 of set 4 | colesberg
# Processing record count 46 of set 4 | galesong
# Processing record count 1 of set 5 | alice springs
# Processing record count 2 of set 5 | yichun
# Processing record count 3 of set 5 | nagapattinam
# Processing record count 4 of set 5 | ravar
# Processing record count 5 of set 5 | norman wells
# City not found. Skipping...
# Processing record count 6 of set 5 | gigmoto
# Processing record count 7 of set 5 | surt
# Processing record count 8 of set 5 | chifeng
# Processing record count 9 of set 5 | souillac
# Processing record count 10 of set 5 | kaputa
# Processing record count 11 of set 5 | otukpo
# Processing record count 12 of set 5 | haines junction
# Processing record count 13 of set 5 | zhigansk
# Processing record count 14 of set 5 | rosetta
# Processing record count 15 of set 5 | upernavik
# Processing record count 16 of set 5 | finschhafen
# Processing record count 17 of set 5 | igrim
# Processing record count 18 of set 5 | shingu
# Processing record count 19 of set 5 | ostrovnoy
# Processing record count 20 of set 5 | yerbogachen
# Processing record count 21 of set 5 | bandarbeyla
# Processing record count 22 of set 5 | teguldet
# Processing record count 23 of set 5 | faratsiho
# Processing record count 24 of set 5 | mizdah
# Processing record count 25 of set 5 | kota belud
# Processing record count 26 of set 5 | san patricio
# Processing record count 27 of set 5 | birjand
# Processing record count 28 of set 5 | preobrazheniye
# Processing record count 29 of set 5 | ekhabi
# Processing record count 30 of set 5 | itarema
# Processing record count 31 of set 5 | suez
# Processing record count 32 of set 5 | aripuana
# Processing record count 33 of set 5 | portland
# Processing record count 34 of set 5 | aklavik
# Processing record count 35 of set 5 | petrodvorets
# Processing record count 36 of set 5 | panjab
# City not found. Skipping...
# Processing record count 37 of set 5 | rio grande city
# Processing record count 38 of set 5 | kamennomostskoye
# Processing record count 39 of set 5 | new iberia
# Processing record count 40 of set 5 | bria
# Processing record count 41 of set 5 | rincon
# Processing record count 42 of set 5 | saint-joseph
# Processing record count 43 of set 5 | wanaka
# Processing record count 44 of set 5 | husavik
# Processing record count 45 of set 5 | lhokseumawe
# Processing record count 46 of set 5 | fortuna
# City not found. Skipping...
# Processing record count 47 of set 5 | kyra
# Processing record count 1 of set 6 | torbay
# Processing record count 2 of set 6 | christchurch
# Processing record count 3 of set 6 | pingliang
# Processing record count 4 of set 6 | mabaruma
# City not found. Skipping...
# Processing record count 5 of set 6 | sfantu gheorghe
# Processing record count 6 of set 6 | tynne
# Processing record count 7 of set 6 | yumen
# Processing record count 8 of set 6 | antofagasta
# Processing record count 9 of set 6 | asau
# Processing record count 10 of set 6 | yarmouth
# Processing record count 11 of set 6 | nyurba
# Processing record count 12 of set 6 | caravelas
# Processing record count 13 of set 6 | karymskoye
# Processing record count 14 of set 6 | monrovia
# Processing record count 15 of set 6 | hithadhoo
# Processing record count 16 of set 6 | paita
# Processing record count 17 of set 6 | kizukuri
# City not found. Skipping...
# Processing record count 18 of set 6 | shahr-e kord
# Processing record count 19 of set 6 | lompoc
# Processing record count 20 of set 6 | karratha
# Processing record count 21 of set 6 | jumla
# Processing record count 22 of set 6 | zhangjiakou
# Processing record count 23 of set 6 | hovd
# Processing record count 24 of set 6 | flinders
# Processing record count 25 of set 6 | castle douglas
# Processing record count 26 of set 6 | cayenne
# Processing record count 27 of set 6 | glenwood springs
# Processing record count 28 of set 6 | kaili
# Processing record count 29 of set 6 | watertown
# Processing record count 30 of set 6 | luwuk
# Processing record count 31 of set 6 | porto belo
# Processing record count 32 of set 6 | burnie
# Processing record count 33 of set 6 | donegal
# City not found. Skipping...
# Processing record count 34 of set 6 | mersing
# Processing record count 35 of set 6 | viedma
# Processing record count 36 of set 6 | chapais
# Processing record count 37 of set 6 | nome
# City not found. Skipping...
# Processing record count 38 of set 6 | talcahuano
# Processing record count 39 of set 6 | presidencia roque saenz pena
# Processing record count 40 of set 6 | venado tuerto
# Processing record count 41 of set 6 | banda aceh
# Processing record count 42 of set 6 | anito
# Processing record count 43 of set 6 | mahbubnagar
# Processing record count 44 of set 6 | diffa
# Processing record count 45 of set 6 | klaksvik
# Processing record count 46 of set 6 | wakkanai
# Processing record count 1 of set 7 | valparaiso
# Processing record count 2 of set 7 | whitehorse
# Processing record count 3 of set 7 | marathon
# Processing record count 4 of set 7 | santa catarina de tepehuanes
# Processing record count 5 of set 7 | coro
# Processing record count 6 of set 7 | pandan
# Processing record count 7 of set 7 | inirida
# Processing record count 8 of set 7 | alegrete
# Processing record count 9 of set 7 | san cristobal
# Processing record count 10 of set 7 | broome
# Processing record count 11 of set 7 | vila franca do campo
# Processing record count 12 of set 7 | san carlos
# Processing record count 13 of set 7 | saldanha
# Processing record count 14 of set 7 | ambilobe
# Processing record count 15 of set 7 | vao
# Processing record count 16 of set 7 | korla
# Processing record count 17 of set 7 | high prairie
# City not found. Skipping...
# Processing record count 18 of set 7 | qaqortoq
# Processing record count 19 of set 7 | manga
# Processing record count 20 of set 7 | batagay-alyta
# Processing record count 21 of set 7 | mahon
# Processing record count 22 of set 7 | kenai
# Processing record count 23 of set 7 | udachnyy
# City not found. Skipping...
# Processing record count 24 of set 7 | kimberley
# Processing record count 25 of set 7 | nelson bay
# City not found. Skipping...
# Processing record count 26 of set 7 | nadym
# City not found. Skipping...
# Processing record count 27 of set 7 | gao
# City not found. Skipping...
# Processing record count 28 of set 7 | biloela
# Processing record count 29 of set 7 | kavieng
# Processing record count 30 of set 7 | general pico
# Processing record count 31 of set 7 | severo-kurilsk
# Processing record count 32 of set 7 | lazaro cardenas
# Processing record count 33 of set 7 | kataysk
# Processing record count 34 of set 7 | ketchikan
# Processing record count 35 of set 7 | timizart
# City not found. Skipping...
# Processing record count 36 of set 7 | bengkulu
# Processing record count 37 of set 7 | marzuq
# Processing record count 38 of set 7 | nikel
# City not found. Skipping...
# Processing record count 39 of set 7 | panubigan
# Processing record count 40 of set 7 | orange cove
# Processing record count 41 of set 7 | turbat
# Processing record count 42 of set 7 | robe
# Processing record count 43 of set 7 | hammerfest
# Processing record count 1 of set 8 | huittinen
# City not found. Skipping...
# Processing record count 2 of set 8 | odweyne
# Processing record count 3 of set 8 | tautira
# Processing record count 4 of set 8 | tecolutilla
# Processing record count 5 of set 8 | mareeba
# Processing record count 6 of set 8 | slave lake
# Processing record count 7 of set 8 | hofn
# Processing record count 8 of set 8 | lagoa
# City not found. Skipping...
# Processing record count 9 of set 8 | dunedin
# Processing record count 10 of set 8 | khash
# Processing record count 11 of set 8 | elizabeth city
# Processing record count 12 of set 8 | la palma
# Processing record count 13 of set 8 | simplicio mendes
# Processing record count 14 of set 8 | peniche
# Processing record count 15 of set 8 | belaya gora
# Processing record count 16 of set 8 | cabedelo
# Processing record count 17 of set 8 | sarande
# Processing record count 18 of set 8 | debre zeyit
# Processing record count 19 of set 8 | longyearbyen
# Processing record count 20 of set 8 | lodja
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 21 of set 8 | north bend
# Processing record count 22 of set 8 | baoro
# City not found. Skipping...
# Processing record count 23 of set 8 | isangel
# Processing record count 24 of set 8 | kruisfontein
# Processing record count 25 of set 8 | onega
# Processing record count 26 of set 8 | sipe sipe
# Processing record count 27 of set 8 | lerik
# Processing record count 28 of set 8 | humboldt
# Processing record count 29 of set 8 | igarka
# Processing record count 30 of set 8 | saint george
# Processing record count 31 of set 8 | minab
# Processing record count 32 of set 8 | benguela
# Processing record count 33 of set 8 | verkhoyansk
# Processing record count 34 of set 8 | xichang
# Processing record count 35 of set 8 | sambir
# Processing record count 36 of set 8 | sitka
# Processing record count 37 of set 8 | hualmay
# Processing record count 38 of set 8 | daudnagar
# Processing record count 39 of set 8 | tres arroyos
# Processing record count 40 of set 8 | tessalit
# Processing record count 41 of set 8 | lexington
# Processing record count 42 of set 8 | jiuquan
# Processing record count 43 of set 8 | izhma
# Processing record count 44 of set 8 | sao joao da barra
# Processing record count 45 of set 8 | bako
# Processing record count 1 of set 9 | tabas
# Processing record count 2 of set 9 | gazimurskiy zavod
# Processing record count 3 of set 9 | brigantine
# Processing record count 4 of set 9 | kavaratti
# Processing record count 5 of set 9 | luderitz
# Processing record count 6 of set 9 | touros
# City not found. Skipping...
# Processing record count 7 of set 9 | samarai
# Processing record count 8 of set 9 | santa isabel do rio negro
# Processing record count 9 of set 9 | olga
# Processing record count 10 of set 9 | te anau
# Processing record count 11 of set 9 | laguna
# Processing record count 12 of set 9 | boulsa
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 13 of set 9 | brownwood
# Processing record count 14 of set 9 | namibe
# Processing record count 15 of set 9 | pimenta bueno
# Processing record count 16 of set 9 | singapore
# Processing record count 17 of set 9 | harrislee
# Processing record count 18 of set 9 | kupang
# Processing record count 19 of set 9 | magaria
# Processing record count 20 of set 9 | gimli
# Processing record count 21 of set 9 | san rafael del sur
# Processing record count 22 of set 9 | weymouth
# Processing record count 23 of set 9 | challapata
# Processing record count 24 of set 9 | colac
# Processing record count 25 of set 9 | los llanos de aridane
# Processing record count 26 of set 9 | kijang
# Processing record count 27 of set 9 | makakilo city
# Processing record count 28 of set 9 | kolarovo
# Processing record count 29 of set 9 | imeni poliny osipenko
# Processing record count 30 of set 9 | rundu
# Processing record count 31 of set 9 | bartica
# Processing record count 32 of set 9 | santa maria
# Processing record count 33 of set 9 | pinheiro
# Processing record count 34 of set 9 | yuxia
# City not found. Skipping...
# Processing record count 35 of set 9 | rio grande
# Processing record count 36 of set 9 | amurzet
# Processing record count 37 of set 9 | baruun-urt
# Processing record count 38 of set 9 | tomari
# Processing record count 39 of set 9 | pskov
# Processing record count 40 of set 9 | honningsvag
# Processing record count 41 of set 9 | barcelos
# Processing record count 42 of set 9 | cairns
# Processing record count 43 of set 9 | maiduguri
# Processing record count 44 of set 9 | ayia galini
# Processing record count 45 of set 9 | roma
# Processing record count 46 of set 9 | dzerzhinsk
# Processing record count 1 of set 10 | narsingi
# Processing record count 2 of set 10 | grand-lahou
# Processing record count 3 of set 10 | yuncheng
# Processing record count 4 of set 10 | hare bay
# City not found. Skipping...
# Processing record count 5 of set 10 | puerto madryn
# City not found. Skipping...
# Processing record count 6 of set 10 | valdivia
# Processing record count 7 of set 10 | baykit
# Processing record count 8 of set 10 | cabo san lucas
# Processing record count 9 of set 10 | jucas
# City not found. Skipping...
# Processing record count 10 of set 10 | lardos
# Processing record count 11 of set 10 | komsomolskiy
# Processing record count 12 of set 10 | gvardeyskoye
# Processing record count 13 of set 10 | san joaquin
# Processing record count 14 of set 10 | rio verde de mato grosso
# Processing record count 15 of set 10 | sobolevo
# Processing record count 16 of set 10 | meulaboh
# City not found. Skipping...
# City not found. Skipping...
# Processing record count 17 of set 10 | kirakira
# Processing record count 18 of set 10 | dinar
# Processing record count 19 of set 10 | ibra
# Processing record count 20 of set 10 | ust-nera
# Processing record count 21 of set 10 | arkhipo-osipovka
# Processing record count 22 of set 10 | dioknisi
# Processing record count 23 of set 10 | rehoboth
# Processing record count 24 of set 10 | coihaique
# Processing record count 25 of set 10 | ostrov
# Processing record count 26 of set 10 | barranca
# Processing record count 27 of set 10 | benidorm
# Processing record count 28 of set 10 | changying
# Processing record count 29 of set 10 | cidreira
# Processing record count 30 of set 10 | labuhan
# Processing record count 31 of set 10 | katobu
# Processing record count 32 of set 10 | nemuro
# Processing record count 33 of set 10 | toora-khem
# Processing record count 34 of set 10 | port lincoln
# Processing record count 35 of set 10 | ivanteyevka
# Processing record count 36 of set 10 | lethem
# Processing record count 37 of set 10 | loa janan
# Processing record count 38 of set 10 | sorland
# Processing record count 39 of set 10 | chokurdakh
# Processing record count 40 of set 10 | grand gaube
# Processing record count 41 of set 10 | namanga
# Processing record count 42 of set 10 | dumas
# Processing record count 43 of set 10 | dayong
# Processing record count 44 of set 10 | high level
# Processing record count 45 of set 10 | xai-xai
# Processing record count 1 of set 11 | hambantota
# Processing record count 2 of set 11 | wasilla
# City not found. Skipping...
# Processing record count 3 of set 11 | jizan
# Processing record count 4 of set 11 | rochegda
# Processing record count 5 of set 11 | kokstad
# City not found. Skipping...
# Processing record count 6 of set 11 | great falls
# Processing record count 7 of set 11 | rebrikha
# Processing record count 8 of set 11 | bonavista
# Processing record count 9 of set 11 | zaozerne
# Processing record count 10 of set 11 | adre
# Processing record count 11 of set 11 | vostok
# Processing record count 12 of set 11 | saurimo
# Processing record count 13 of set 11 | tosham
# Processing record count 14 of set 11 | tura
# City not found. Skipping...
# Processing record count 15 of set 11 | sal rei
# Processing record count 16 of set 11 | paray-le-monial
# Processing record count 17 of set 11 | santa marinella
# Processing record count 18 of set 11 | nanakuli
# Processing record count 19 of set 11 | utinga
# Processing record count 20 of set 11 | besancon
# Processing record count 21 of set 11 | kaitangata
# City not found. Skipping...
# Processing record count 22 of set 11 | kuytun
# Processing record count 23 of set 11 | vilyuysk
# Processing record count 24 of set 11 | tilichiki
# Processing record count 25 of set 11 | soyo
# Processing record count 26 of set 11 | tirano
# Processing record count 27 of set 11 | senanga
# City not found. Skipping...
# Processing record count 28 of set 11 | russell
# Processing record count 29 of set 11 | college
# Processing record count 30 of set 11 | emba
# Processing record count 31 of set 11 | benghazi
# Processing record count 32 of set 11 | shache
# City not found. Skipping...
# Processing record count 33 of set 11 | pangnirtung
# Processing record count 34 of set 11 | akyab
# Processing record count 35 of set 11 | plettenberg bay
# Processing record count 36 of set 11 | paamiut
# Processing record count 37 of set 11 | kahului
# Processing record count 38 of set 11 | pio xii
# Processing record count 39 of set 11 | kralendijk
# Processing record count 40 of set 11 | kanniyakumari
# Processing record count 41 of set 11 | cochabamba
# Processing record count 42 of set 11 | shellbrook
# Processing record count 43 of set 11 | barranquilla
# Processing record count 44 of set 11 | visnes
# Processing record count 1 of set 12 | abilene
# Processing record count 2 of set 12 | salto del guaira
# Processing record count 3 of set 12 | saint-pierre
# Processing record count 4 of set 12 | dinhata
# Processing record count 5 of set 12 | terrace
# Processing record count 6 of set 12 | dunda
# City not found. Skipping...
# Processing record count 7 of set 12 | dawlatabad
# Processing record count 8 of set 12 | linqing
# City not found. Skipping...
# Processing record count 9 of set 12 | harper
# Processing record count 10 of set 12 | orlovskiy
# Processing record count 11 of set 12 | benito juarez
# Processing record count 12 of set 12 | road town
# Processing record count 13 of set 12 | pavlovsk
# Processing record count 14 of set 12 | lorengau
# Processing record count 15 of set 12 | mayo
# Processing record count 16 of set 12 | maues
# Processing record count 17 of set 12 | sur
# Processing record count 18 of set 12 | amol
# Processing record count 19 of set 12 | narsaq
# Processing record count 20 of set 12 | point pedro
# Processing record count 21 of set 12 | maragogi
# Processing record count 22 of set 12 | dhidhdhoo
# City not found. Skipping...
# Processing record count 23 of set 12 | oussouye
# Processing record count 24 of set 12 | kaeo
# Processing record count 25 of set 12 | santa isabel
# Processing record count 26 of set 12 | baturaja
# Processing record count 27 of set 12 | krasnoarmeysk
# Processing record count 28 of set 12 | tukrah
# Processing record count 29 of set 12 | serowe
# Processing record count 30 of set 12 | pevek
# Processing record count 31 of set 12 | ponta delgada
# Processing record count 32 of set 12 | camacha
# Processing record count 33 of set 12 | tucker
# Processing record count 34 of set 12 | esil
# Processing record count 35 of set 12 | eenhana
# Processing record count 36 of set 12 | stancuta
# Processing record count 37 of set 12 | burriana
# Processing record count 38 of set 12 | kem
# Processing record count 39 of set 12 | nouakchott
# Processing record count 40 of set 12 | les cayes
# Processing record count 41 of set 12 | beringovskiy
# Processing record count 42 of set 12 | kilifi
# Processing record count 43 of set 12 | bayir
# Processing record count 44 of set 12 | constitucion
# Processing record count 45 of set 12 | riviere-au-renard
# Processing record count 46 of set 12 | champerico
# Processing record count 47 of set 12 | tual
# City not found. Skipping...
# Processing record count 1 of set 13 | cam ranh
# Processing record count 2 of set 13 | barbastro
# City not found. Skipping...
# Processing record count 3 of set 13 | bluefield
# Processing record count 4 of set 13 | lusambo
# Processing record count 5 of set 13 | yershov
# Processing record count 6 of set 13 | sibolga
# Processing record count 7 of set 13 | hargeysa
# Processing record count 8 of set 13 | milkovo
# Processing record count 9 of set 13 | harindanga
# Processing record count 10 of set 13 | barcelona
# Processing record count 11 of set 13 | iskateley
# Processing record count 12 of set 13 | evensk
# Processing record count 13 of set 13 | yeppoon
# Processing record count 14 of set 13 | kyren
# Processing record count 15 of set 13 | chicama
# Processing record count 16 of set 13 | zionsville
# Processing record count 17 of set 13 | rawlins
# Processing record count 18 of set 13 | bitung
# Processing record count 19 of set 13 | nosy varika
# Processing record count 20 of set 13 | muriwai beach
# Processing record count 21 of set 13 | piacabucu
# Processing record count 22 of set 13 | grand forks
# Processing record count 23 of set 13 | avera
# Processing record count 24 of set 13 | lasa
# Processing record count 25 of set 13 | northam
# Processing record count 26 of set 13 | bernardino de campos
# Processing record count 27 of set 13 | mezhova
# Processing record count 28 of set 13 | fereydun kenar
# Processing record count 29 of set 13 | zacualpan
# Processing record count 30 of set 13 | pathein
# City not found. Skipping...
# Processing record count 31 of set 13 | atlantic beach
# Processing record count 32 of set 13 | guaca
# Processing record count 33 of set 13 | salalah
# Processing record count 34 of set 13 | morristown
# Processing record count 35 of set 13 | tucuman
# Processing record count 36 of set 13 | mana
# Processing record count 37 of set 13 | atasu
# Processing record count 38 of set 13 | puerto escondido
# Processing record count 39 of set 13 | faanui
# Processing record count 40 of set 13 | victoria point
# City not found. Skipping...
# Processing record count 41 of set 13 | taos
# Processing record count 42 of set 13 | jining
# Processing record count 43 of set 13 | las vegas
# Processing record count 44 of set 13 | mapiripan
# Processing record count 45 of set 13 | yumbe
# Processing record count 46 of set 13 | puerto gaitan
# Processing record count 1 of set 14 | mazagao
# Processing record count 2 of set 14 | berlevag
# Processing record count 3 of set 14 | comodoro rivadavia
# City not found. Skipping...
# Processing record count 4 of set 14 | noumea
# Processing record count 5 of set 14 | mutis
# Processing record count 6 of set 14 | fomboni
# Processing record count 7 of set 14 | mount isa
# Processing record count 8 of set 14 | lixourion
# Processing record count 9 of set 14 | morshansk
# City not found. Skipping...
# Processing record count 10 of set 14 | liverpool
# Processing record count 11 of set 14 | porto novo
# Processing record count 12 of set 14 | hobyo
# Processing record count 13 of set 14 | zahesi
# Processing record count 14 of set 14 | turukhansk
# Processing record count 15 of set 14 | banepa
# Processing record count 16 of set 14 | olinda
# Processing record count 17 of set 14 | tazovskiy
# Processing record count 18 of set 14 | klyuchi
# Processing record count 19 of set 14 | chateaudun
# Processing record count 20 of set 14 | petapa
# City not found. Skipping...
# Processing record count 21 of set 14 | xuzhou
# Processing record count 22 of set 14 | port said
# Processing record count 23 of set 14 | waitati
# Processing record count 24 of set 14 | dickinson
# Processing record count 25 of set 14 | utete
# Processing record count 26 of set 14 | makokou
# Processing record count 27 of set 14 | rapid valley
# Processing record count 28 of set 14 | prince rupert
# Processing record count 29 of set 14 | puerto del rosario
# Processing record count 30 of set 14 | pogar
# City not found. Skipping...
# Processing record count 31 of set 14 | poum
# Processing record count 32 of set 14 | lobito
# Processing record count 33 of set 14 | jasper
# Processing record count 34 of set 14 | tocopilla
# Processing record count 35 of set 14 | awjilah
# Processing record count 36 of set 14 | bowmore
# Processing record count 37 of set 14 | rovaniemi
# Processing record count 38 of set 14 | wuda
# Processing record count 39 of set 14 | camapua
# Processing record count 40 of set 14 | kasongo-lunda
# Processing record count 41 of set 14 | robertsport
# City not found. Skipping...
# Processing record count 42 of set 14 | fairview
# Processing record count 43 of set 14 | blagoyevo
# Processing record count 44 of set 14 | tarakan
# Processing record count 45 of set 14 | lluta
# Processing record count 1 of set 15 | juan lacaze
# Processing record count 2 of set 15 | tateyama
# Processing record count 3 of set 15 | vila
# Processing record count 4 of set 15 | miri
# Processing record count 5 of set 15 | havre-saint-pierre
# Processing record count 6 of set 15 | bathsheba
# Processing record count 7 of set 15 | kulhudhuffushi
# Processing record count 8 of set 15 | ixtapa
# Processing record count 9 of set 15 | nerkunram
# Processing record count 10 of set 15 | diamantino
# Processing record count 11 of set 15 | maceio
# City not found. Skipping...
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 647

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661  -42.0278     68.95        72          13
# 1           Hobart -42.8794  147.3294     57.25        73          75
# 2         Hermanus -34.4187   19.2345     56.01        79          33
# 3         Victoria  22.2855  114.1577     79.97        85          96
# 4        Cape Town -33.9258   18.4232     56.12        89           0
# 5   Vestmannaeyjar  63.4427  -20.2734     48.25        80          15
# 6   Chernyshevskiy  63.0128  112.4714     61.54        40          97
# 7         Tasiilaq  65.6145  -37.6368     32.16        71          57
# 8             Faya  18.3851   42.4509     61.32        11          35
# 9          Ahipara -35.1667  173.1667     62.58        69         100
#
#    Wind Speed Current Description Country                 Date
# 0        5.91          few clouds      BR  2022-05-22 03:42:02
# 1       10.36       broken clouds      AU  2022-05-22 03:46:20
# 2        7.09    scattered clouds      ZA  2022-05-22 03:46:21
# 3       13.00     overcast clouds      HK  2022-05-22 03:46:21
# 4        5.75           clear sky      ZA  2022-05-22 03:45:42
# 5       10.13          few clouds      IS  2022-05-22 03:46:22
# 6        8.52     overcast clouds      RU  2022-05-22 03:46:23
# 7        2.35       broken clouds      GL  2022-05-22 03:46:23
# 8        5.28    scattered clouds      SA  2022-05-22 03:46:23
# 9       12.57     overcast clouds      NZ  2022-05-22 03:46:24

# %%
#Create Organized DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     68.95        72          13
# 1           Hobart      AU -42.8794  147.3294     57.25        73          75
# 2         Hermanus      ZA -34.4187   19.2345     56.01        79          33
# 3         Victoria      HK  22.2855  114.1577     79.97        85          96
# 4        Cape Town      ZA -33.9258   18.4232     56.12        89           0
# 5   Vestmannaeyjar      IS  63.4427  -20.2734     48.25        80          15
# 6   Chernyshevskiy      RU  63.0128  112.4714     61.54        40          97
# 7         Tasiilaq      GL  65.6145  -37.6368     32.16        71          57
# 8             Faya      SA  18.3851   42.4509     61.32        11          35
# 9          Ahipara      NZ -35.1667  173.1667     62.58        69         100
#
#    Wind Speed Current Description
# 0        5.91          few clouds
# 1       10.36       broken clouds
# 2        7.09    scattered clouds
# 3       13.00     overcast clouds
# 4        5.75           clear sky
# 5       10.13          few clouds
# 6        8.52     overcast clouds
# 7        2.35       broken clouds
# 8        5.28    scattered clouds
# 9       12.57     overcast clouds

# %%
#Create output CSV
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
